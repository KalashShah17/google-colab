# %% [markdown]
# #TOPIC
# #WINE QUALITY PREDICTION USING SUPPORT VECTOR MECHANISM
# ________________________________________________________________________________

# %% [markdown]
# Objective
#
# Here our objective is to train and test on the provided dataset from YBI foundation github repository (csv file) and then predict the quality of wine further

# %% [markdown]
# #Get Understanding about Data Set
#
# White wine has twelve variables.
#   1. fixed acidity
#   2. volatile acidity
#   3. citric acid
#   4. residual sugar
#   5. chlorides
#   6. free sulfur dioxide
#   7. total surfur dioxide
#   8. density
#   9. pH
#   10. sulphates
#   11. alcohol
#   12. quality

# %% [markdown]
# #Import Library

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# #Import CSV as DataFrame

# %%
df= pd.read_csv(r'https://raw.githubusercontent.com/YBIFoundation/Dataset/refs/heads/main/WhiteWineQuality.csv', sep=';')

# %% [markdown]
# #Get First 5 rows of DataFrame

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %% [markdown]
# #Get Information Of DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# #Get The Summary Statistics

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %% [markdown]
# #Get Column Names

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# #Get Shape of DataFrame

# %%
df.shape
# Out:
# (4898, 12)

# %% [markdown]
# #get unique value (class or label) in y variable

# %%
df['quality'].value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %%
df.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             7.600000          0.333250     0.336000        6.392500
# 4             7.129448          0.381227     0.304233        4.628221
# 5             6.933974          0.302011     0.337653        7.334969
# 6             6.837671          0.260564     0.338025        6.441606
# 7             6.734716          0.262767     0.325625        5.186477
# 8             6.657143          0.277400     0.326514        5.671429
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.054300            53.325000            170.600000  0.994884
# 4         0.050098            23.358896            125.279141  0.994277
# 5         0.051546            36.432052            150.904598  0.995263
# 6         0.045217            35.650591            137.047316  0.993961
# ...

# %% [markdown]
# #Define y (dependant or label or target variable) and X (independent or features or attribute variable)

# %%
y=df['quality']

# %%
y.shape
# Out:
# (4898,)

# %%
y
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 4893    6
# 4894    5
# 4895    6
# 4896    7
# 4897    6
# Name: quality, Length: 4898, dtype: int64

# %%
X = df[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']]

# %% [markdown]
# or use .drop function to defien X

# %%
X = df.drop(['quality'], axis=1)

# %%
X.shape
# Out:
# (4898, 11)

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# #Get X variable standardized
# Standardization of datasets is a common requirement for many machine learning estimators implemented in scikit-learn; they might behave badly if the individual features do not more or less look like standard normally distributed data: Gaussion with zero mean and unit variance
# Next approach is go for MinMax Scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss= StandardScaler()

# %%
X = ss.fit_transform(X)

# %%
X
# Out:
# array([[ 1.72096961e-01, -8.17699008e-02,  2.13280202e-01, ...,
#         -1.24692128e+00, -3.49184257e-01, -1.39315246e+00],
#        [-6.57501128e-01,  2.15895632e-01,  4.80011213e-02, ...,
#          7.40028640e-01,  1.34184656e-03, -8.24275678e-01],
#        [ 1.47575110e+00,  1.74519434e-02,  5.43838363e-01, ...,
#          4.75101984e-01, -4.36815783e-01, -3.36667007e-01],
#        ...,
#        [-4.20473102e-01, -3.79435433e-01, -1.19159198e+00, ...,
#         -1.31315295e+00, -2.61552731e-01, -9.05543789e-01],
#        [-1.60561323e+00,  1.16673788e-01, -2.82557040e-01, ...,
#          1.00495530e+00, -9.62604939e-01,  1.85757201e+00],
#        [-1.01304317e+00, -6.77100966e-01,  3.78559282e-01, ...,
#          4.75101984e-01, -1.48839409e+00,  1.04489089e+00]])

# %% [markdown]
# #Get Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =0.3,stratify= y, random_state= 2529)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3428, 11), (1470, 11), (3428,), (1470,))

# %% [markdown]
# #Get model train

# %%
from sklearn.svm import SVC

# %%
svc= SVC()

# %%
svc.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# #Get Model Prediction

# %%
y_pred = svc.predict(X_test)

# %%
y_pred.shape
# Out:
# (1470,)

# %%
y_pred
# Out:
# array([5, 7, 5, ..., 5, 5, 5])

# %% [markdown]
# #Get model Evaluation

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[  0   0   1   5   0   0   0]
#  [  0   2  25  22   0   0   0]
#  [  0   3 273 160   1   0   0]
#  [  0   0 122 515  23   0   0]
#  [  0   0   6 191  67   0   0]
#  [  0   0   0  39  14   0   0]
#  [  0   0   0   0   1   0   0]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         6
#            4       0.40      0.04      0.07        49
#            5       0.64      0.62      0.63       437
#            6       0.55      0.78      0.65       660
#            7       0.63      0.25      0.36       264
#            8       0.00      0.00      0.00        53
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.58      1470
#    macro avg       0.32      0.24      0.25      1470
# weighted avg       0.57      0.58      0.55      1470
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# #Get model re-run with 2 class reated for wine quality
#
# Wine quality 3,4,5 labelled as 0
#
# Wine Quality 6,7,8,9 labelled as 1

# %%
y= df['quality'].apply(lambda y_value: 1 if y_value>=6 else 0)

# %%
y.value_counts()
# Out:
# quality
# 1    3258
# 0    1640
# Name: count, dtype: int64

# %% [markdown]
# #Get Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =0.3,stratify= y, random_state= 2529)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3428, 11), (1470, 11), (3428,), (1470,))

# %% [markdown]
# #Get model train

# %%
from sklearn.svm import SVC

# %%
svc= SVC()

# %%
svc.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# #Get Model Prediction

# %%
y_pred = svc.predict(X_test)

# %%
y_pred.shape
# Out:
# (1470,)

# %%
y_pred
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %% [markdown]
# #Get model Evaluation

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[289 203]
#  [124 854]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.59      0.64       492
#            1       0.81      0.87      0.84       978
#
#     accuracy                           0.78      1470
#    macro avg       0.75      0.73      0.74      1470
# weighted avg       0.77      0.78      0.77      1470

# %% [markdown]
# #Get Future Predictions
#
# Lets select a random sample from existing dataset as new value
#
# Steps to follow
#
# 1. Extract a random row using sample function
# 2. Separate X and y
# 3. Standardize X
# 4. Predict

# %%
df_new= df.sample(1)

# %%
df_new
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2681            7.2              0.19         0.27            11.2      0.061
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2681                 46.0                 149.0  0.99772  2.99       0.59
#
#       alcohol  quality
# 2681      9.3        6

# %%
df_new.shape
# Out:
# (1, 12)

# %%
X_new = df_new.drop(['quality'], axis=1)

# %%
X_new = ss.fit_transform(X_new)

# %%
y_pred_new = svc.predict(X_new)

# %%
y_pred_new
# Out:
# array([1])

# %% [markdown]
# #Explaination
#
# So here we have uesd Support Vector Mechanism from SKlearn library to further predict the quality of wine based on features provided in the dataset
# We used 70 % of data to train and 30 % of data to test the accuracy
